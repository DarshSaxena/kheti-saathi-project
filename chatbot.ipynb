# %%
# !pip install openai

# %%
from openai import OpenAI

client = OpenAI(api_key="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")

def chatbot():
    print(" Kheti Saathi LLM Chatbot (type 'exit' to stop)\n")

    while True:
        query = input("You: ")

        if query.lower() == "exit":
            print("Chatbot: Goodbye ")
            break
        if query.lower()=="hi":
            print("Chatbot:Hi,How may I help you today")
            

        try:
            response = get_llm_response(query)
            print("Chatbot:", response)

        except Exception as e:
            print("Error:", e)


def get_llm_response(query):
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": "You are an expert agricultural assistant. Give clear, practical, farmer-friendly advice."
            },
            {"role": "user", "content": query}
        ]
    )

    return completion.choices[0].message.content


chatbot()
# Out:
#  Kheti Saathi LLM Chatbot (type 'exit' to stop)
# You:  hi
# Chatbot:Hi,How may I help you today
# Error: Connection error.
# You:  rice
# Error: Connection error.
